# %% [markdown]
# # Prediction using glmnet

# %% [markdown]
# ##### loading libraries

# %%
library(data.table)
library(caret)
library(pROC)

# %% [markdown]
# ##### loading datasets

# %%
load("../data_processed/projetDataBase.Rda")
projetTrain    = sub.projetTrain.base
projetValid    = sub.projetValid.base

# %% [markdown]
# ##### making subsets for train and test of our TRAIN DATA

# %%
set.seed(0)
split = sample(nrow(projetTrain), floor(0.3*nrow(projetTrain)))
sub.train = projetTrain[split,]
sub.test  = projetTrain[-split,]

# %% [markdown]
# ##### defining search grid to find the best alpha-beta penalisation

# %%
lambda.grid = seq(0.005,0.006,length=5)
alpha.grid  = seq(0.43,0.6,length=5)
srchGrid    = expand.grid(.alpha=alpha.grid,.lambda=lambda.grid)
trnCtl      = trainControl(method="repeatedCV",number=5,repeats=2) # cadrage coss valisation

# %% [markdown]
# ##### computing glmnet model

# %%
glmnet.model = train(target~.,data=sub.train,method="glmnet",tuneGrid=srchGrid,trControl=trnCtl,standardize=TRUE)#,maxit=1000000)

# %%
plot(glmnet.model) # visialusation des performances pour les diffï¿½rentes valeurs de alpha et beta"
# Out:
# plot without title

# %% [markdown]
# ##### model description

# %%
glmnet.model
# Out:
# glmnet
#
# 15414 samples
#   129 predictor
#     2 classes: 'KO', 'OK'
#
# No pre-processing
# Resampling: Cross-Validated (5 fold, repeated 2 times)
# Summary of sample sizes: 12331, 12331, 12332, 12331, 12331, 12332, ...
# Resampling results across tuning parameters:
#
#   alpha   lambda   Accuracy   Kappa
#   0.4300  0.00500  0.8234713  0.5948840
#   0.4300  0.00525  0.8232442  0.5942283
#   0.4300  0.00550  0.8232443  0.5941040
#   0.4300  0.00575  0.8234064  0.5943999
#   0.4300  0.00600  0.8232767  0.5939942
#   0.4725  0.00500  0.8230172  0.5937586
#   0.4725  0.00525  0.8232442  0.5941826
#   0.4725  0.00550  0.8233091  0.5941637
#   0.4725  0.00575  0.8232118  0.5938207
#   0.4725  0.00600  0.8234065  0.5941205
#   0.5150  0.00500  0.8231793  0.5940294
#   0.5150  0.00525  0.8232118  0.5939649
#   0.5150  0.00550  0.8232767  0.5939687
#   0.5150  0.00575  0.8231469  0.5936249
#   0.5150  0.00600  0.8236660  0.5946879
#   0.5575  0.00500  0.8230821  0.5936887
#   0.5575  0.00525  0.8233416  0.5941740
#   0.5575  0.00550  0.8233416  0.5940478
#   0.5575  0.00575  0.8236335  0.5946017
#   0.5575  0.00600  0.8234390  0.5939853
#   0.6000  0.00500  0.8236335  0.5948914
#   0.6000  0.00525  0.8235686  0.5946002
#   0.6000  0.00550  0.8234065  0.5940691
#   0.6000  0.00575  0.8234065  0.5939000
#   0.6000  0.00600  0.8232768  0.5934360
#
# Accuracy was used to select the optimal model using  the largest value.
# The final values used for the model were alpha = 0.515 and lambda = 0.006.

# %% [markdown]
# ##### prediction on test set

# %%
result.predicted.prob <- predict(glmnet.model, sub.test , type="prob") # Prediction

# %% [markdown]
# ##### AUC curve

# %%
result.roc <- roc(sub.test$target, result.predicted.prob$OK) # Draw ROC curve.
plot(result.roc, print.thres="best", print.thres.best.method="closest.topleft")
# Out:
# Call:
# roc.default(response = sub.test$target, predictor = result.predicted.prob$OK)
#
# Data: result.predicted.prob$OK in 24122 controls (sub.test$target KO) < 11845 cases (sub.test$target OK).
# Area under the curve: 0.8984
# plot without title

# %%
result.coords <- coords(result.roc, "best", best.method="closest.topleft", ret=c("threshold", "accuracy"))
print(result.coords)#to get threshold and accuracy

# %% [markdown]
# ##### saving model

# %%
save(glmnet.model, file="workspace_glmnet.Rdata")

# %% [markdown]
# ##### generating the response for the validation subset

# %%
result.predicted.prob.valid <- predict(glmnet.model, projetValid , type="prob") # Prediction on validation subset
projetValid$Id = as.character(projetValid$Id)
validation.results = cbind(projetValid[,"Id",with=FALSE],result.predicted.prob.valid)
write.csv(validation.results, file = "validation_results.csv")
